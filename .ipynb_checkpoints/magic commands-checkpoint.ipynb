# %% [markdown]
# # Magic commands

# %%
# %lsmagic #lists all magic commands available in jupyter notebook
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
 # %alias monik echo "monik is great at python but maybe needs to learn java"

# %%
monik
# Out:
# "monik is great at python but maybe needs to learn java"

# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 540A-1F88
#
#  Directory of C:\Users\hp\Desktop\personal python notes
#
# 25-Apr-22  04:00 PM    <DIR>          .
# 25-Apr-22  04:00 PM    <DIR>          ..
# 25-Apr-22  03:52 PM    <DIR>          .ipynb_checkpoints
# 11-Jul-20  12:12 AM               447 1.txt
# 08-Jul-20  02:57 AM            27,707 3-Numpy Tutorial.ipynb
# 09-Aug-20  02:18 AM           242,025 4- Pandas tutorial-Copy1 (1).ipynb
# 08-Jul-20  03:04 AM            22,880 4- Pandas tutorial-Copy1.ipynb
# 28-Jan-21  03:46 PM           154,386 4.5-Matplotlib.ipynb
# 16-Jul-20  01:48 PM           298,076 5- Seaborn.ipynb
# 11-Aug-20  02:56 AM           139,890 Assignment3 (1).ipynb
# 16-Jul-20  01:37 PM            46,442 bill_authentication.csv
# 17-Dec-20  12:50 AM    <DIR>          book
# 16-Jul-20  01:36 PM           194,323 Classified Data
# 17-Dec-20  06:30 PM               105 coursera.csv
# 11-Apr-20  04:11 PM             9,755 Daily Views.xlsx
# ...

# %%
#shows the content of file in pop window
# %pycat dict1.py

# %%
# load the file and auto-comments the magic commands, tben have to rerun the cell to execute the loaded file
# %load dict1.py
info = {"name": "monik", "lastname": "garg"}
print(info["name"])
print(info.get("age"))  # if key doesn't exit then returns none vale instead of keyerror
info["dob"] = "3nov1999"  # can add key and value or cj
print(info["dob"])
# Out:
# monik
# None
# 3nov1999

# %%
# %run dict1 # to directly run a .py python file in jupyter notebook
# Out:
# monik
# None
# 3nov1999

# %%
import monik

# %%
# to get details about import library. tells about type, location, content
??monik

# %%
# shift+tab over below statement gives few details like signature, docstring, location and type
monik.print_status()
# Out:
# sed life ;/

# %%
import numpy as np

# %%
# shift+tab gives less information for more shift+tab+tab for most info shift+tab+tab+tab
# doing this to np, random and rand will give different information respectively
np.random.rand(10)
# Out:
# array([0.68094221, 0.98781693, 0.94703939, 0.9148149 , 0.27377203,
#        0.16004798, 0.02297769, 0.90942785, 0.29087879, 0.74785627])

# %%
# can store and load gobal variable across jupyter notebook
num = 515
# %store num
# Out:
# Stored 'num' (int)

# %%
# now to access this variable in another notebook do the following
# %store -r num
num
# Out:
# 515

# %%
# gives details about the magic command
# %time?

# %%
# time required to run the statement
# %time [i*i for i in range(1000)]
# Out:
# Wall time: 998 µs
# [0,
#  1,
#  4,
#  9,
#  16,
#  25,
#  36,
#  49,
#  64,
#  81,
#  100,
#  121,
#  144,
#  169,
#  196,
#  225,
#  256,
#  289,
#  324,
#  361,
#  400,
#  441,
#  484,
#  529,
#  576,
#  625,
#  676,
#  729,
#  784,
#  841,
#  900,
#  961,
#  1024,
#  1089,
#  1156,
#  1225,
#  1296,
#  1369,
#  1444,
#  1521,
#  1600,
#  1681,
#  1764,
#  1849,
#  1936,
#  2025,
#  2116,
#  2209,
#  2304,
#  2401,
#  2500,
#  2601,
#  2704,
#  2809,
#  2916,
#  3025,
#  3136,
#  3249,
#  3364,
#  3481,
#  3600,
#  3721,
#  3844,
#  3969,
#  4096,
#  4225,
#  4356,
#  4489,
#  4624,
#  4761,
#  4900,
#  5041,
#  5184,
#  5329,
#  5476,
#  5625,
#  5776,
#  5929,
#  6084,
#  6241,
#  6400,
#  6561,
#  6724,
#  6889,
#  7056,
#  7225,
#  7396,
#  7569,
#  7744,
#  7921,
#  8100,
#  8281,
#  8464,
#  8649,
#  8836,
#  9025,
#  9216,
#  9409,
#  9604,
#  9801,
#  10000,
#  10201,
#  10404,
#  10609,
#  10816,
#  11025,
#  11236,
#  11449,
#  11664,
#  11881,
#  12100,
#  12321,
# ...

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
monik.print_status()
# Out:
# sed life ;/
# add it now, adding even more

# %%
# %autoreload 0

# %%
monik.print_status()
# Out:
# sed life ;/, hello anyone there
# add it now, adding even more

# %%
# prefix with ! if want to run linux commands in jupyter notebok
# !echo "hello world"
# Out:
# "hello world"

# %% [markdown]
# ### can run different kernels in jupyter notebook as html, bash, js

# %%
# %%javascript
#
# let a = 5
# alert("a="+a)

# %% [markdown]
# *monik* --> ITALICS<br>
# **monik** --> BOLD<br>
# ***monik*** --> ITALICS & BOLD<br>
# ```HELLO``` --> FOR CODE SNIPPET<br>
# [click for google](https://www.google.com/search?q=google&oq=google&aqs=chrome..69i57j46i131i199i433i465i512j69i60l3j69i65l3.4784j0j7&sourceid=chrome&ie=UTF-8)<br>
