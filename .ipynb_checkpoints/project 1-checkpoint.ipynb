# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt
# %matplotlib inline

dataset = pd.read_csv('time_series_2019-ncov-Confirmed (1).csv')
data = dataset.drop(['Province/State','Lat','Long'],axis=1)

# %%
c = data.keys()
c = c[1:]

# %%
for i in c:
    a = data[i]
    j = 0
    count = 0
    while j < len(a):
        if a[j] == 0:
            count+=1
        j+=1
    if count >= 340:
        data = data.drop([i],axis=1)
key = data.keys()

# %%
df1 = data.iloc[:,0]
df1 = np.array(df1)
df = data.values

# %%
for ii in range(0,487):
    aa = df1[ii]
    for jj in range(ii,487):
        bb = df1[jj] 
        if aa == bb:
            if ii == jj:
                continue
            else:
                for qq in range(1,20):
                    df[ii,qq] = df[ii,qq] + df[jj,qq]
                    df[jj,qq] = 0
                
        else:
            continue

# %%
d = pd.DataFrame(df,columns=key)

# %%
m = d.iloc[:,1:]
m = m.mean(axis=1)

# %%
for i in range(0,487):
    if m[i] == 0:
        d = d.drop([i],axis=0)
d
# Out:
#            Country/Region 03-04-2020 03-05-2020 03-06-2020 03-07-2020  \
# 0                Thailand         43         47         48         50
# 1                   Japan        331        360        420        461
# 2               Singapore        110        117        130        138
# 3                   Nepal          1          1          1          1
# 4                Malaysia         50         50         83         93
# 5                  Canada         33         37         49         54
# 6               Australia         52         55         60         63
# 9                Cambodia          1          1          1          1
# 10              Sri Lanka          1          1          1          1
# 11                Germany        262        482        670        799
# 12                Finland          6         12         15         15
# 13   United Arab Emirates         27         29         29         45
# ...

# %%
da = d.head(20)
da.plot.line(figsize=(35,25));
