# %%
import pandas as pd

# %%
df=pd.read_excel("us occ master tracker.xlsx",header=1)
df=df.set_index('eim id')
#df

# %%
df1=pd.read_excel('us remarks.xlsx')
df1=df1.set_index('eim id')
#df1

# %%
df['eim_remarks']=df1['remarks']
df
# Out:
#         s.no transfer type transfer METHOD  receiving app inst ID  \
# eim id
# 56531      1          file     sftp puwhed                 237478
# 52833      2          file             NaN                 237478
# 74364      3          file     sftp puwhed                 237478
# 84055      4          file         demised                 237478
# 21430      5          file     sftp puwhed                 237478
# 43367      6          file         demised                 237478
# 36783      7          file         demised                 237478
# 44359      8          file     sftp puwhed                 237478
# 13661      9          file         demised                 237478
# 84642     10          file     sftp puwhed                 237478
# 72134     11          file         demised                 237478
# 23277     12          file     sftp puwhed                 237478
# 31867     13          file     sftp puwhed                 237478
# ...

# %%
output_data=df[['transfer METHOD','receiving app gbgf name','eim_remarks']]
output_data
# Out:
#        transfer METHOD receiving app gbgf name        eim_remarks
# eim id
# 56531      sftp puwhed                 risk it       this is hell
# 52833              NaN                 risk it          not vcool
# 74364      sftp puwhed                 risk it             boieee
# 84055          demised                 risk it        lets hanggg
# 21430      sftp puwhed                taken it           yooooooo
# 43367          demised                 risk it         fuckkkkkkk
# 36783          demised                taken it          shitttttt
# 44359      sftp puwhed                 risk it                omg
# 13661          demised                 risk it               damn
# 84642      sftp puwhed                 risk it          soup song
# 72134          demised                taken it          flop song
# 23277      sftp puwhed                 risk it            thunder
# 31867      sftp puwhed                 risk it       one repbulic
# ...

# %%
master.to_excel('output.xlsx')

# %%
df2=pd.read_excel('output.xlsx')

# %%
df2
# Out:
#     eim id transfer METHOD receiving app gbgf name        eim_remarks
# 0    56531     sftp puwhed                 risk it       this is hell
# 1    52833             NaN                 risk it          not vcool
# 2    74364     sftp puwhed                 risk it             boieee
# 3    84055         demised                 risk it        lets hanggg
# 4    21430     sftp puwhed                taken it           yooooooo
# 5    43367         demised                 risk it         fuckkkkkkk
# 6    36783         demised                taken it          shitttttt
# 7    44359     sftp puwhed                 risk it                omg
# 8    13661         demised                 risk it               damn
# 9    84642     sftp puwhed                 risk it          soup song
# 10   72134         demised                taken it          flop song
# 11   23277     sftp puwhed                 risk it            thunder
# ...
